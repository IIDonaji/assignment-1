# %%
# Initialize Otter
import otter
grader = otter.Notebook("hw1-task2.ipynb")

# %% [markdown]
# # Homework 1 Task 2: Simple Linear Regression
# ## Do eDNA and Traditional Sampling Detect the Same Number of Fish Species?
#
#
# ---
#
# ### Background
#
# Environmental DNA (eDNA) sampling detects species by collecting and sequencing genetic material shed into the water — no nets or electrofishing required. Traditional methods require direct capture or observation. This dataset, the same as used in Task 1, compiles results from **68 freshwater lake surveys** across multiple published studies, comparing species detected by each method.
#
# Your goal is to investigate whether **eDNA-based species richness** (`dna_richness`) can predict **traditional species richness** (`trad_richness`) — the number of species found by conventional gear. This is a question for conservation monitoring: if the two methods broadly agree, eDNA could replace expensive field surveys.
#
# You will build and evaluate a simple linear regression model from scratch using NumPy, and then verify your results with `sklearn` and `statsmodels`.
#
# ---
#
#
# The dataset has the following key columns:
#
# | Column | Description |
# |---|---|
# | `author` | First author of the primary study |
# | `area_ha` | Lake area (hectares) |
# | `dna_richness` | Number of fish species detected by eDNA |
# | `trad_richness` | Number of fish species detected by conventional surveys |
# | `dna_only` | Number of species found **only** by eDNA |
# | `trad_only` | Number of species found **only** by conventional surveys |
# | `shared` | Number of species found by **both** methods |
# | `union` | Total unique species (`dna_only + trad_only + shared`) |
# | `marker_cat` | Whether single or multiple genetic markers were used (single vs. multiple eDNA markers) |
# | `gear_cat` | Whether single or multiple conventional survey gear types were used (single vs. multiple) |
# | `total_vol_liter` | Total volume of water sampled (litres) |

# %% [markdown]
# ### Setup: Load libraries and read in data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv('lakes_data.csv') 
df.head()
# Out:
#    author  year_pub    area_ha  dna_richness  trad_richness  dna_only  \
# 0  Civade      2016      545.0            14             18         1
# 1   Doble      2020  3290000.0            92             62        41
# 2   Evans      2017        2.0            15             10         5
# 3   Fujii      2019        9.0             0              7         0
# 4   Fujii      2019        5.0             2              8         0
#
#    trad_only  shared  union  marker_count         locus marker_cat  gear_cat  \
# 0          5      13     19             1           12s     single    single
# 1         11      51    103             4       12s_16s   multiple    single
# 2          0      10     15             3  12s_16s_cytb   multiple  multiple
# 3          7       0      7             1           12s     single  multiple
# 4          6       2      8             1           12s     single  multiple
#
#   match_effort  field_reps  rep_vol_liter  total_vol_liter
# 0          yes           3          45.00           135.00
# 1          yes          21          10.00           210.00
# 2          yes          31           0.25             7.75
# 3           no           1           1.00             1.00
# 4           no           1           1.00             1.00

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ---
# ## Step 1: Visualise the Relationship
#
# Create an exploratory data visualization exploring the relationship between `dna_richness` and `trad_richness`.

# %%
plt.scatter(df['dna_richness'], df['trad_richness'], alpha=0.6)
plt.xlabel('DNA Richness')
plt.ylabel('Traditional Richness')
plt.title('eDNA vs Traditonal Species Richness')

max_val = df[['dna_richness', 'trad_richness']].max().max()
plt.plot([0, max_val], [0, max_val], 'r--', label='1:1 line')
plt.legend()
plt.show()

# %% [markdown]
# > **Q1:** Does there appear to be a relationship between the two variables? Describe the direction, form, and approximate strength.

# %% [markdown]
# There appears to be a postive, linear relationship between eDNA richness and traditonal richness. As eDNA species detection increase so does traditional survey detection. The relationship is moderately strong, most points cluster near the 1:1 line at low richness values, but there is increasing scatter at high values. Two outliers are visible at high richness values, one above the 1:1 line where traditional surverys detected more species than eDNA surveys, and one below where eDNA detected considerbaly more species than traditional survery. Most of the points fall close to the 1:1 line suggesting reasonable agreement between the two methods.

# %% [markdown]
# <!-- END QUESTION -->
#
# ---
# ## Step 2: Fit the Regression
#
# Use `numpy` and the formula below to manually calculate β₁ and β₀. Store your coefficients in the `beta_1` and `beta_0` variables. Then, create a scatter plot of `trad_richness` and `dna_richness` (likely similar to the plot you created above!). Add the fitted line to the scatter plot, and the equation of the line as a legend item.
#
# $$\hat{\beta}_1 = \frac{\sum(x_i - \bar{x})(y_i - \bar{y})}{\sum(x_i - \bar{x})^2} \qquad \hat{\beta}_0 = \bar{y} - \hat{\beta}_1\bar{x}$$

# %%
x = df['dna_richness'].values # predictor
y = df['trad_richness'].values # response

beta_1 = np.sum((x - x.mean()) * (y - y.mean()) / np.sum((x - x.mean())**2))
beta_0 = y.mean() - beta_1 * x.mean()

print(f"\u03b2\u2081     = {beta_1:.4f}")
print(f"\u03b2\u2080     = {beta_0:.4f}")

# Scatter plot with fitted line
plt.scatter(x, y, alpha=0.6)
plt.plot(x, beta_0 + beta_1 * x, 'r-', label=f'y = {beta_0:.2f} + {beta_1:.2f}x')
plt.xlabel('eDNA Richness')
plt.ylabel('Traditional Richness')
plt.title('eDNA vs Traditional Species Richness')
plt.legend()
plt.show()
# Out:
# β₁     = 0.6519
# β₀     = 4.0013

# %%
grader.check("q2")
# Out:
# q2 results:
#     q2 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(beta_1, 0.6519, atol=0.001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q2 0
#         Failed example:
#             np.isclose(beta_1, 0.6519, atol=0.001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q2 - 2 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(beta_0, 4.0013, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q2 1
#         Failed example:
#             np.isclose(beta_0, 4.0013, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ---
# ## Step 3: Interpret the Coefficients
#
#
#
# > **Q2:** Interpret the slope in plain language. Include units.
#
# For every additional species detected by eDNA, traditional survey detect 0.6519 more species on average. This suggests traditional survey detect slighlt fewer species than eDNA overall.
#
#
#
# > **Q3:** Interpret the intercept. Is it ecologically meaningful?
#
# When eDNA detects 0 species, the model predicts traditional surverys would detect 4.0013 species. This is not ecological meaningful because a lake with zero eDNA detections is unrealistic, and you wouldn't expect traditional surveys to find 4 species if eDNA found none.

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ---
# ## Step 4: Compute Standard Errors
#
# Use `numpy` and the formula below to manually calculate the standard errors. Store the RSE in a variable called `RSE`, the standard error of β₁ in a variable called `SE_beta_1`, and the standard error of β₀ in a variable called `SE_beta_0`.
#
# $$SS_{xx} = \sum(x_i - \bar{x})^2$$
#
# $$RSE = \sqrt{\frac{RSS}{n-2}}$$
#
# $$SE(\hat{\beta}_1) = \frac{RSE}{SS_{xx}}$$
#
# $$SE(\hat{\beta}_0) = RSE \sqrt{\frac{1}{n} + \frac{\bar{x}^2}{SS_{xx}}}$$

# %%
# predicted value
y_pred = beta_0 + beta_1 * x
# RSS
RSS   = np.sum((y - y_pred)**2)
# spread of x
SS_xx = np.sum((x - x.mean())**2)
# number of values in x
n     = len(df)

RSE       = np.sqrt(RSS / (n - 2))
SE_beta_1 = RSE / np.sqrt(SS_xx)
SE_beta_0 = RSE * np.sqrt(1/n + x.mean()**2 / SS_xx)

print(f"RSE      = {RSE:.4f}  (species)")
print(f"SE(\u03b2\u2081)   = {SE_beta_1:.4f}")
print(f"SE(\u03b2\u2080)   = {SE_beta_0:.4f}")
# Out:
# RSE      = 4.7441  (species)
# SE(β₁)   = 0.0446
# SE(β₀)   = 0.7974

# %%
grader.check("q4")
# Out:
# q4 results:
#     q4 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(RSE, 4.7441, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q4 0
#         Failed example:
#             np.isclose(RSE, 4.7441, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q4 - 2 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(SE_beta_1, 0.0446, atol=0.001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q4 1
#         Failed example:
#             np.isclose(SE_beta_1, 0.0446, atol=0.001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q4 - 3 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(SE_beta_0, 0.7974, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q4 2
#         Failed example:
#             np.isclose(SE_beta_0, 0.7974, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_

# %% [markdown]
# ---
# ## Step 5: Manually Calculate 95% Confidence Intervals for $\beta_0$ and $\beta_1$
#
# Using the formula below, manually calculate an approximate 95% confidence interval for β₀ and β₁.
#
# $$95\% \text{ CI} \simeq \hat{\beta}_i \pm 2 \times SE(\hat{\beta})$$

# %%
CI_beta_1_lower = beta_1 - 2 * SE_beta_1
CI_beta_1_upper = beta_1 + 2 * SE_beta_1

CI_beta_0_lower = beta_0 - 2 * SE_beta_0
CI_beta_0_upper = beta_0 + 2 * SE_beta_0

print(f"\n95% CI for \u03b2\u2081 (slope):  ({CI_beta_1_lower:.4f},  {CI_beta_1_upper:.4f})")
print(f"95% CI for \u03b2\u2080 (intercept): ({CI_beta_0_lower:.4f},  {CI_beta_0_upper:.4f})")
# Out:
# 95% CI for β₁ (slope):  (0.5627,  0.7411)
# 95% CI for β₀ (intercept): (2.4064,  5.5962)

# %%
grader.check("q5")
# Out:
# q5 results:
#     q5 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(CI_beta_1_lower, 0.5627, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q5 0
#         Failed example:
#             np.isclose(CI_beta_1_lower, 0.5627, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q5 - 2 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(CI_beta_1_upper, 0.7411, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q5 1
#         Failed example:
#             np.isclose(CI_beta_1_upper, 0.7411, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q5 - 3 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(CI_beta_0_lower, 2.4064, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q5 2
#         Failed example:
#             np.isclose(CI_beta_0_lower, 2.4064, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q5 - 4 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(CI_beta_0_upper, 5.5962, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q5 3
#         Failed example:
#             np.isclose(CI_beta_0_upper, 5.5962, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# > **Q4:** Interpret the 95% CI for the slope in plain language.

# %% [markdown]
# We are 95% confident that for every additional species detected by eDNA, traditional surveys detect between 0.56 and 0.74 more species on average. The interval does not include 1.0, traditional surveys consistently detect fewer species than eDNA, since it does not include 0, the relationship is statistically significant.

# %% [markdown]
# <!-- END QUESTION -->
#
# ---
# ## Step 6: Assess Model Accuracy — R²
#
# Manually calculate the R² using the formula below. Store your answer in the `R2` variable.
#
# $$R^2 = 1 - \frac{RSS}{TSS} \qquad TSS = \sum_{i=1}^{n}(y_i - \bar{y})^2$$

# %%
R2     = 1 - RSS / np.sum((y - y.mean())**2)

print(f"R\u00b2     = {R2:.4f}")
# Out:
# R²     = 0.7640

# %%
grader.check("q7")
# Out:
# q7 results:
#     q7 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(R2, 0.7640, atol=0.001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q7 0
#         Failed example:
#             np.isclose(R2, 0.7640, atol=0.001)
#         Expected:
#             True
#         Got:
#             np.True_

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# > **Q5:** Interpret the R² in the context of this problem.

# %% [markdown]
# eDNA richness explains 76.4% of the variation in traditional species richness. This indicates a strong relationship between the two methods, most of the differences in traditional survey counts across lakes can be predicated from eDNA detections alone. The remaining 23.6% in unexplained, likely due to factors such as sampling effort, gear type, or lake-specific conditions.

# %% [markdown]
# <!-- END QUESTION -->
#
# ---
# ## Step 7: Verify with `sklearn`
#
# Let's confirm our manual OLS results using `sklearn`'s `LinearRegression`.
#
# > **Note:** `sklearn` expects a 2D feature matrix, so we need to reshape `X` from
# > shape `(n,)` to `(n, 1)` using `.reshape(-1, 1)` before fitting.
#
# 1. **Fit the model** — `LinearRegression().fit(X_2d, Y)` finds the same OLS solution as
#    our manual β₁ and β₀ formulas.
# 2. **Extract coefficients** — `.coef_[0]` is the slope, `.intercept_` is the intercept.
# 3. **Compute R²** — `r2_score(Y, y_pred)` uses the $R^2 = 1 - RSS/TSS$. formula, where `y_pred = your_fitted_model.predict(X_2d)`
#
# 4. Create a table that compares the manually calculated and `LinearRegression()` generated slope, intercept, and R².
#
# If your manual calculations are correct, all three values should match `sklearn`'s output
# to at least four decimal places. Any discrepancy beyond floating-point rounding
# indicates a bug in your manual formulas.

# %%
X_2d = x.reshape(-1, 1)
model = LinearRegression().fit(X_2d, y)
y_pred_sk = model.predict(X_2d)

sk_slope     = model.coef_[0]
sk_intercept = model.intercept_
sk_r2        = r2_score(y, y_pred_sk)

print(f"sklearn  slope     = {sk_slope:.4f},  manual slope     = {beta_1:.4f}")
print(f"sklearn  intercept = {sk_intercept:.4f},  manual intercept = {beta_0:.4f}")
print(f"sklearn  R\u00b2        = {sk_r2:.4f},  manual R\u00b2        = {R2:.4f}")
# Out:
# sklearn  slope     = 0.6519,  manual slope     = 0.6519
# sklearn  intercept = 4.0013,  manual intercept = 4.0013
# sklearn  R²        = 0.7640,  manual R²        = 0.7640

# %%
grader.check("q9")
# Out:
# q9 results:
#     q9 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sk_slope, beta_1, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q9 0
#         Failed example:
#             np.isclose(sk_slope, beta_1, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q9 - 2 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sk_intercept, beta_0, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q9 1
#         Failed example:
#             np.isclose(sk_intercept, beta_0, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q9 - 3 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sk_r2, R2, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q9 2
#         Failed example:
#             np.isclose(sk_r2, R2, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_

# %% [markdown]
# ---
# ## Step 8: Verify with `statsmodels`
#
# `sklearn` is optimized for **prediction**: it fits models efficiently and scores them, but it deliberately leaves out statistical inference (standard errors, p-values, confidence intervals).
#
# `statsmodels` is designed for **inference**: it fits the same OLS model but reports the full regression table — coefficients, standard errors, t-statistics, p-values, and confidence intervals — matching what you'd see in a statistics textbook.
#
#
# 1. Import `statsmodels.api as sm`.
# 2. Add a constant (intercept) column to `X` using `sm.add_constant()`.
# 3. Fit the model with `sm.OLS(Y, X_sm).fit()` and call `.summary()` to display the full regression table.
# 4. Extract the slope, intercept, and R² from the fitted model and compare them to your numpy and sklearn results. Store the statsmodels slope in `sm_slope`, the intercept in `sm_intercept`, and R² in `sm_r2`.
#
# If all three methods are correct, the coefficients and R² should match to at least four decimal places.

# %%
import statsmodels.api as sm

X_sm = sm.add_constant(x)
sm_model = sm.OLS(y, X_sm).fit()
print(sm_model.summary())

sm_intercept = sm_model.params[0]
sm_slope     = sm_model.params[1]
sm_r2        = sm_model.rsquared
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                     213.7
# Date:                Fri, 10 Apr 2026   Prob (F-statistic):           2.25e-22
# Time:                        20:46:47   Log-Likelihood:                -201.34
# No. Observations:                  68   AIC:                             406.7
# Df Residuals:                      66   BIC:                             411.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.0013      0.797      5.018      0.000       2.409       5.593
# x1             0.6519      0.045     14.618      0.000       0.563       0.741
# ==============================================================================
# Omnibus:                       39.645   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              119.718
# Skew:                           1.786   Prob(JB):                     1.01e-26
# Kurtosis:                       8.430   Cond. No.                         24.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
grader.check("q10")
# Out:
# q10 results:
#     q10 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sm_slope, beta_1, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q10 0
#         Failed example:
#             np.isclose(sm_slope, beta_1, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q10 - 2 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sm_intercept, beta_0, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q10 1
#         Failed example:
#             np.isclose(sm_intercept, beta_0, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q10 - 3 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sm_r2, R2, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q10 2
#         Failed example:
#             np.isclose(sm_r2, R2, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# > **Q6:** Look at the **p-values** for the slope (`dna_richness`) and intercept (`const`) in the statsmodels summary.
# >
# > - What does the p-value for the **slope** tell you? Is the relationship between eDNA richness and traditional richness statistically significant? How do you know?

# %% [markdown]
# The p-value for the slope (x1) is 0.000 (essentially zero), which is far below the 0.05 treshold. This means the relationship between eDNA richness and traditional richness is statistically significant, there is virtully zero chance this relationship occured by chance. For every additional species detected by eDNA, traditional survery detect 0.65 more species on average.

# %% [markdown]
# <!-- END QUESTION -->

# %% [markdown]
# ---
#
# **Run the cell below to receive credit for all auto graded questions.**

# %%
grader.check_all()
# Out:
# q10 results:
#     q10 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sm_slope, beta_1, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q10 0
#         Failed example:
#             np.isclose(sm_slope, beta_1, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q10 - 2 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sm_intercept, beta_0, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q10 1
#         Failed example:
#             np.isclose(sm_intercept, beta_0, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q10 - 3 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sm_r2, R2, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q10 2
#         Failed example:
#             np.isclose(sm_r2, R2, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_
#
# q2 results:
#     q2 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(beta_1, 0.6519, atol=0.001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q2 0
#         Failed example:
#             np.isclose(beta_1, 0.6519, atol=0.001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q2 - 2 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(beta_0, 4.0013, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q2 1
#         Failed example:
#             np.isclose(beta_0, 4.0013, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
# q4 results:
#     q4 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(RSE, 4.7441, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q4 0
#         Failed example:
#             np.isclose(RSE, 4.7441, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q4 - 2 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(SE_beta_1, 0.0446, atol=0.001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q4 1
#         Failed example:
#             np.isclose(SE_beta_1, 0.0446, atol=0.001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q4 - 3 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(SE_beta_0, 0.7974, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q4 2
#         Failed example:
#             np.isclose(SE_beta_0, 0.7974, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
# q5 results:
#     q5 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(CI_beta_1_lower, 0.5627, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q5 0
#         Failed example:
#             np.isclose(CI_beta_1_lower, 0.5627, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q5 - 2 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(CI_beta_1_upper, 0.7411, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q5 1
#         Failed example:
#             np.isclose(CI_beta_1_upper, 0.7411, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q5 - 3 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(CI_beta_0_lower, 2.4064, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q5 2
#         Failed example:
#             np.isclose(CI_beta_0_lower, 2.4064, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q5 - 4 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(CI_beta_0_upper, 5.5962, atol=0.01)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q5 3
#         Failed example:
#             np.isclose(CI_beta_0_upper, 5.5962, atol=0.01)
#         Expected:
#             True
#         Got:
#             np.True_
#
# q7 results:
#     q7 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(R2, 0.7640, atol=0.001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q7 0
#         Failed example:
#             np.isclose(R2, 0.7640, atol=0.001)
#         Expected:
#             True
#         Got:
#             np.True_
#
# q9 results:
#     q9 - 1 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sk_slope, beta_1, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q9 0
#         Failed example:
#             np.isclose(sk_slope, beta_1, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q9 - 2 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sk_intercept, beta_0, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q9 1
#         Failed example:
#             np.isclose(sk_intercept, beta_0, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_
#
#     q9 - 3 result:
#         ❌ Test case failed
#         Trying:
#             np.isclose(sk_r2, R2, atol=0.0001)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q9 2
#         Failed example:
#             np.isclose(sk_r2, R2, atol=0.0001)
#         Expected:
#             True
#         Got:
#             np.True_
